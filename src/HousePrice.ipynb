# %%
import pandas as pd

df = pd.read_csv("../data-master/data_combined_cleaned.csv")
label='SalePrice'
df = df.drop(columns=["Id"])
df = df[~df.SalesPrice.isnull()]
df.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave  None      Reg
# 1          20       RL         80.0     9600   Pave  None      Reg
# 2          60       RL         68.0    11250   Pave  None      IR1
# 3          70       RL         60.0     9550   Pave  None      IR1
# 4          60       RL         84.0    14260   Pave  None      IR1
#
#   LandContour LotConfig LandSlope    ...     PoolArea PoolQC Fence  \
# 0         Lvl    Inside       Gtl    ...            0   None  None
# 1         Lvl       FR2       Gtl    ...            0   None  None
# 2         Lvl    Inside       Gtl    ...            0   None  None
# 3         Lvl    Corner       Gtl    ...            0   None  None
# 4         Lvl       FR2       Gtl    ...            0   None  None
#
#   MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition SalesPrice
# 0        None       0       2    2008        WD         Normal   208500.0
# 1        None       0       5    2007        WD         Normal   181500.0
# 2        None       0       9    2008        WD         Normal   223500.0
# 3        None       0       2    2006        WD        Abnorml   140000.0
# 4        None       0      12    2008        WD         Normal   250000.0
#
# [5 rows x 79 columns]

# %%
import numpy as np
from sklearn import preprocessing, model_selection, linear_model, metrics, pipeline

# %%
target = "SalesPrice"
X = df.drop(columns=[target])
X = pd.get_dummies(X, drop_first=True)
columns = X.columns
X = X.values.astype("float")
y = np.log(df[target])

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y,
                           test_size = 0.3, random_state = 1)

pipe = pipeline.Pipeline([
    ("poly", preprocessing.PolynomialFeatures(degree=1
                                    , include_bias=False)),
    ("scaler", preprocessing.StandardScaler()),
    ("est", linear_model.LinearRegression())
])


pipe.fit(X_train, y_train)

y_train_pred = pipe.predict(X_train)
y_test_pred = pipe.predict(X_test)

print("training r2", metrics.r2_score(y_train, y_train_pred))
print("test r2", metrics.r2_score(y_test, y_test_pred))

print("training rmse:"
    , np.sqrt(metrics.mean_squared_error(y_train, y_train_pred)))
print("test rmse:"
      , np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
est = pipe.steps[-1][-1]
pd.DataFrame({"feature": columns, "coefficient": est.coef_})
# Out:
# training r2 0.949457939631394
# test r2 -2.54435098583593e+21
# training rmse: 0.08606297564899322
# test rmse: 21928419930.745697
#       coefficient                feature
# 0    1.302997e-02             MSSubClass
# 1    2.013699e-03            LotFrontage
# 2    3.158463e-02                LotArea
# 3    5.655668e-02            OverallQual
# 4    3.472947e-02            OverallCond
# 5    5.039211e-02              YearBuilt
# 6    1.530530e-02           YearRemodAdd
# 7   -3.999379e-03             MasVnrArea
# 8    6.034020e+10             BsmtFinSF1
# 9    2.147349e+10             BsmtFinSF2
# 10   5.712425e+10              BsmtUnfSF
# 11  -5.837611e+10            TotalBsmtSF
# 12  -3.675277e+10               1stFlrSF
# 13  -4.075538e+10               2ndFlrSF
# 14  -4.500649e+09           LowQualFinSF
# 15   4.961583e+10              GrLivArea
# 16   8.759022e-03           BsmtFullBath
# 17   1.631379e-03           BsmtHalfBath
# 18   7.315636e-03               FullBath
# 19   9.500027e-03               HalfBath
# 20   1.478386e-02           BedroomAbvGr
# 21  -9.944975e-03           KitchenAbvGr
# 22  -1.374245e-03           TotRmsAbvGrd
# 23   1.022530e-02             Fireplaces
# 24  -1.276255e-02            GarageYrBlt
# 25   5.341053e-03             GarageCars
# 26   3.922093e-02             GarageArea
# 27   1.008797e-02             WoodDeckSF
# 28   9.412169e-03            OpenPorchSF
# 29   1.195562e-02          EnclosedPorch
# ..            ...                    ...
# 228  2.406216e-02          GarageCond_Gd
# 229 -9.909553e+08        GarageCond_None
# 230  3.252506e-02          GarageCond_Po
# 231  6.826067e-02          GarageCond_TA
# 232 -3.124237e-03           PavedDrive_P
# 233  2.309799e-03           PavedDrive_Y
# 234 -8.215534e+01              PoolQC_Fa
# 235  1.084498e-02              PoolQC_Gd
# 236  3.231889e-02            PoolQC_None
# 237 -1.966715e-03             Fence_GdWo
# 238  6.461143e-04            Fence_MnPrv
# 239  2.892792e-03             Fence_MnWw
# 240  5.970001e-04             Fence_None
# 241  1.069303e-01       MiscFeature_None
# 242  2.085209e-02       MiscFeature_Othr
# 243  9.059942e-02       MiscFeature_Shed
# 244  0.000000e+00       MiscFeature_TenC
# 245  9.979010e-04           SaleType_CWD
# 246  5.681038e-03           SaleType_Con
# 247  7.675171e-03         SaleType_ConLD
# 248 -4.803658e-03         SaleType_ConLI
# 249 -3.733635e-04         SaleType_ConLw
# 250  4.483795e-02           SaleType_New
# 251  8.882761e-03           SaleType_Oth
# 252 -5.652905e-03            SaleType_WD
# 253  1.862049e-03  SaleCondition_AdjLand
# 254  1.124382e-02   SaleCondition_Alloca
# 255  9.738803e-04   SaleCondition_Family
# 256  2.905917e-02   SaleCondition_Normal
# 257 -1.691341e-02  SaleCondition_Partial
#
# [258 rows x 2 columns]
